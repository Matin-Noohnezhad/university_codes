# %%
c = 0
z = 0
for numberOfGraph in range(10000):
    Edges = random_matrix(ZZ, 10, 10, x=0, y=2)
    for i in range(10):
        for j in range(10):
            if(j>=i):
                Edges[j,i] = Edges[i,j]
            c = Edges[i,j] + c
        c = c+Edges[i,i]
        if(c%2 ==0):
            z = z + 1
            c = 0
    if(z == 10):
        A = Graph(Edges)
        A.plot().show()
        break
    else:
        z = 0
