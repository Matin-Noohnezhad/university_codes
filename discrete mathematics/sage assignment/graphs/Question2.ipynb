# %%
for numberOfGraph in range(10):
    Edges = random_matrix(ZZ, 20, 20, x=0, y=2)
    for i in range(20):
        for j in range(20):
            if(j>=i):
                Edges[j,i] = Edges[i,j]
    A = Graph(Edges)
    A.plot().show()
