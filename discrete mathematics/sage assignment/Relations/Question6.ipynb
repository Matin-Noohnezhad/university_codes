# %% [markdown]
# <h1>Question9 - Relations</h1>

# %%
A = posets.PentagonPoset().chains(); A
print(list(A))
N5 = posets.PentagonPoset(); N5
# Out:
# [[], [0], [0, 1], [0, 1, 4], [0, 2], [0, 2, 3], [0, 2, 3, 4], [0, 2, 4], [0, 3], [0, 3, 4], [0, 4], [1], [1, 4], [2], [2, 3], [2, 3, 4], [2, 4], [3], [3, 4], [4]]
