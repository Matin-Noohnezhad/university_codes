# %% [markdown]
# <h1>Question8 - Relations</h1>

# %%
P = Posets(5)
for p in P: print(p.cover_relations())
# Out:
# []
# [[3, 4]]
# [[2, 3], [2, 4]]
# [[1, 2], [1, 3], [1, 4]]
# [[0, 1], [0, 2], [0, 3], [0, 4]]
# [[0, 1], [0, 3], [0, 4], [1, 2]]
# [[0, 1], [0, 2], [0, 4], [1, 3], [2, 3]]
# [[0, 1], [0, 2], [0, 3], [1, 4], [2, 4], [3, 4]]
# [[1, 2], [1, 4], [2, 3]]
# [[0, 1], [0, 4], [1, 2], [1, 3]]
# [[1, 2], [1, 3], [2, 4], [3, 4]]
# [[0, 1], [0, 2], [1, 3], [2, 3], [3, 4]]
# [[0, 1], [0, 3], [1, 2], [3, 4]]
# [[0, 1], [0, 3], [1, 2], [1, 4], [3, 4]]
# [[0, 1], [0, 2], [1, 3], [1, 4], [2, 3], [2, 4]]
# [[2, 3], [3, 4]]
# [[1, 2], [2, 3], [2, 4]]
# [[0, 1], [1, 2], [1, 3], [1, 4]]
# [[3, 4], [2, 4]]
# [[2, 3], [1, 3], [3, 4]]
# [[1, 2], [0, 2], [2, 3], [2, 4]]
# [[3, 4], [2, 4], [1, 4]]
# [[2, 3], [1, 3], [0, 3], [3, 4]]
# [[3, 4], [2, 4], [1, 4], [0, 4]]
# [[3, 4], [2, 4], [0, 1]]
# [[2, 3], [2, 4], [1, 3], [0, 4]]
# [[2, 3], [2, 4], [1, 3], [1, 4], [0, 4]]
# [[2, 3], [2, 4], [1, 3], [1, 4], [0, 3], [0, 4]]
# [[1, 2], [0, 2], [2, 3], [3, 4]]
# [[2, 3], [1, 3], [3, 4], [0, 4]]
# ...
