# %% [markdown]
# <h1>Problem 3</h1>

# %%
p = polygon([(2,2), (2,4), (4,4), (4,2)], rgbcolor=(1,0,0), fill=True)
c = circle((3,3), 1, rgbcolor=(1,1,1), fill=True)
p.plot()+c.plot()

# %% [markdown]
# #
