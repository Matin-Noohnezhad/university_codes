# %%
<h1>Trees: Computations and Explorations-Question2</h1>

# %%
numberOfVertices = 7
for g in graphs(numberOfVertices):
     if(g.is_connected()):
            if(numberOfVertices - len(g.edges()) == 1):
                g.plot().show()
